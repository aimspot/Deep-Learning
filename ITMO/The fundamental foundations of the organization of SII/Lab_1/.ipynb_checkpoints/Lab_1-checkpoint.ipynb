# %%
import pandas as pd
import numpy as np
import statistics as std
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn import preprocessing

# %%
df = pd.read_excel('data/ID_data_mass_18122012.xlsx', sheet_name='VU', header = 1)
# Out:
# D:\Users\misha\Documents\Anaconda\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
df.describe()
# Out:
#         Unnamed: 0           Unnamed: 1  Глубина манометра     Dшт  Руст Рзаб  \
# count          186                  186              186.0  186.00   186  186
# unique          15                  178               40.0   15.00   174  180
# top          21303  2008-02-08 00:00:00             3548.5    9.53   206    -
# freq            19                    2               10.0   38.00     3    4
#
#        Pлин  Руст.1 Рзаб.1 Рлин  ...  Рпл. Тек (Карноухов)    Pсб       Pсб.1  \
# count   186     186    186  186  ...                   183  179.0  179.000000
# unique  178     140    174  170  ...                    26  114.0  114.000000
# top       -     215      -    -  ...                     -   89.6   88.428325
# freq      7       7      4   11  ...                    47    6.0    6.000000
#
#              Ro_g Ro_c  Ro_w  Удельная плотность газа  G_total   КГФ  КГФ.1
# count   24.000000   94    24                     94.00      24    24  71.00
# unique   7.000000   26     2                     22.00      24    24  50.00
# top      0.787416  782  1000                      0.66    кг/с  г/м3   0.18
# freq     7.000000   11    23                      9.00       1     1   4.00
#
# [4 rows x 34 columns]

# %%
df.head(25)
# Out:
#    Unnamed: 0           Unnamed: 1 Глубина манометра    Dшт        Руст  \
# 0           №           дд.мм.гггг                 м     мм        бара
# 1         804  2008-06-05 00:00:00            3576.3   7.94       249.6
# 2         804  2008-06-06 00:00:00            3576.3   9.53       233.5
# 3         804  2008-06-07 00:00:00            3576.3  11.11       213.4
# 4         804  2008-06-08 00:00:00            3576.3   12.7       191.6
# 5         804  2008-06-09 00:00:00            3576.3  14.29       171.9
# 6         804  2011-06-17 00:00:00            3576.3   9.53       199.5
# 7         807  2004-09-16 00:00:00              3590   7.93   284.31795
# 8         807  2004-09-16 00:00:00              3590  11.11   270.94305
# 9         807  2004-09-17 00:00:00              3590  14.28  245.510475
# 10        807  2004-09-17 00:00:00              3590  17.46  209.641425
# 11        807  2007-05-09 00:00:00              3667   7.94         252
# 12        807  2007-05-10 00:00:00              3667   9.53         250
# 13        807  2007-05-11 00:00:00              3667  11.11         240
# 14        807  2007-05-12 00:00:00              3667   12.7         228
# 15        807  2009-08-18 00:00:00              3579   7.94  259.608696
# 16        807  2009-08-22 00:00:00              3579   9.53  239.423077
# 17        807  2009-08-26 00:00:00              3579  11.11  213.428571
# 18        807  2009-08-30 00:00:00              3579   12.7  194.242424
# 19        807  2009-09-03 00:00:00              3579  14.29         166
# 20        807  2011-09-09 00:00:00            3582.5   9.53         206
# 21      20503  2007-10-03 00:00:00              3653   7.94       323.1
# 22      20503  2007-10-04 00:00:00              3653   9.53  272.692308
# 23      20503  2007-10-05 00:00:00              3653   12.7  202.153846
# 24      20503  2007-10-06 00:00:00              3653  14.29  165.846154
#
#           Рзаб        Pлин      Руст.1      Рзаб.1        Рлин  ...  \
# 0         бара        бара         бар         бар         бар  ...
# 1        370.1       101.8         249       359.6       101.8  ...
# 2        364.6       101.3         231       338.1       102.4  ...
# 3        357.1       101.6         211       314.8       100.6  ...
# 4        347.4        98.4         187       291.5          99  ...
# 5        337.7        99.2         169       270.3        99.5  ...
# 6        286.4  106.361669       199.5       286.6      106.19  ...
# 7   391.823775           -   284.31795  391.823775           -  ...
# 8     384.2244           -   270.94305    384.2244           -  ...
# 9   371.912399           -  245.510475  371.912399           -  ...
# 10  346.192061           -  209.641425  346.192061           -  ...
# 11  354.333525  102.932004         252       354.2  101.565484  ...
# 12       350.2  103.186902         250       349.1  103.322581  ...
# 13         344  105.671499         240       344.1   105.58871  ...
# 14       336.7  108.100063         228         343  108.144839  ...
# 15      365.86  103.471415         259       365.9  101.420323  ...
# 16      342.27  103.200466         239       342.3      104.18  ...
# 17      312.27  103.187111         212       312.3       103.0  ...
# 18      291.74  103.229928         194       291.7  103.917419  ...
# 19      263.03   107.37756         166         263  107.536667  ...
# 20         292  105.507978         206         292      105.03  ...
# 21       440.5  108.886435         314       442.7   99.167355  ...
# 22       388.7   89.652839         268       388.6   86.747194  ...
# 23       308.8   97.877045         197       308.7   92.457903  ...
# 24       270.5    79.95275         162       270.4   81.146774  ...
#
#    Рпл. Тек (Карноухов)    Pсб       Pсб.1      Ro_g   Ro_c   Ro_w  \
# 0                   МПа    атм         бар     кг/м3  кг/м3  кг/м3
# 1                     -   93.6   92.376018  0.806017    801   1000
# 2                     -   92.9   91.685171  0.806017    801   1000
# 3                     -   91.4   90.204787  0.806017    801   1000
# 4                     -   89.2   88.033555  0.806017    801   1000
# 5                     -   89.7   88.527017  0.806017    801   1000
# 6                     -   90.7    89.51394    0.8127  789.8   1000
# 7                  51.7    NaN         NaN       NaN    NaN    NaN
# 8                  51.7    NaN         NaN       NaN    NaN    NaN
# 9                  51.7    NaN         NaN       NaN    NaN    NaN
# 10                 51.7    NaN         NaN       NaN    NaN    NaN
# 11                 50.1  100.9   99.580558       NaN    787    NaN
# 12                 50.1  100.1   98.791019       NaN    787    NaN
# 13                 50.1    102  100.666173       NaN    787    NaN
# 14                 50.1  103.8  102.442635       NaN    787    NaN
# 15                    -   93.2   91.981248       NaN  793.7    NaN
# 16                    -     92   90.796941       NaN  793.7    NaN
# 17                    -   93.7    92.47471       NaN  793.7    NaN
# 18                    -   89.6   88.428325       NaN  793.7    NaN
# 19                    -   90.3   89.119171       NaN  793.7    NaN
# 20                  NaN   92.1   90.895633       NaN    783    NaN
# 21                 56.8   99.4   98.100173  0.787416    798   1000
# 22                 56.8   99.7    98.39625  0.787416    798   1000
# 23                 56.8   99.2   97.902788  0.787416    798   1000
# 24                 56.8   98.9   97.606711  0.787416    798   1000
#
#    Удельная плотность газа    G_total         КГФ     КГФ.1
# 0                       б/р      кг/с        г/м3  т/тыс.м3
# 1                  0.669449  2.782623    311.9094       NaN
# 2                  0.669449  3.697781    288.6003       NaN
# 3                  0.669449  4.515073    248.7906       NaN
# 4                  0.669449  5.217673    223.5591       NaN
# 5                  0.669449  5.765092    215.1486       NaN
# 6                     0.675  3.076542  241.130794       NaN
# 7                       NaN       NaN         NaN       NaN
# 8                       NaN       NaN         NaN       NaN
# 9                       NaN       NaN         NaN       NaN
# 10                      NaN       NaN         NaN       NaN
# 11                    0.659       NaN         NaN     0.188
# 12                    0.659       NaN         NaN     0.178
# 13                    0.659       NaN         NaN     0.169
# 14                    0.659       NaN         NaN     0.162
# 15                    0.661       NaN         NaN      0.23
# 16                    0.661       NaN         NaN     0.201
# 17                    0.661       NaN         NaN     0.172
# 18                    0.661       NaN         NaN     0.157
# 19                    0.661       NaN         NaN     0.141
# 20                    0.672       NaN         NaN     0.172
# 21                    0.654   4.23237  385.415949       NaN
# 22                    0.654  4.714503   295.50288       NaN
# 23                    0.654   5.72787  255.681127       NaN
# 24                    0.654  5.775314  233.960444       NaN
#
# [25 rows x 34 columns]

# %%
df = df[1:]

# %%
df.head(25)
# Out:
#    Unnamed: 0           Unnamed: 1 Глубина манометра    Dшт        Руст  \
# 1         804  2008-06-05 00:00:00            3576.3   7.94       249.6
# 2         804  2008-06-06 00:00:00            3576.3   9.53       233.5
# 3         804  2008-06-07 00:00:00            3576.3  11.11       213.4
# 4         804  2008-06-08 00:00:00            3576.3   12.7       191.6
# 5         804  2008-06-09 00:00:00            3576.3  14.29       171.9
# 6         804  2011-06-17 00:00:00            3576.3   9.53       199.5
# 7         807  2004-09-16 00:00:00              3590   7.93   284.31795
# 8         807  2004-09-16 00:00:00              3590  11.11   270.94305
# 9         807  2004-09-17 00:00:00              3590  14.28  245.510475
# 10        807  2004-09-17 00:00:00              3590  17.46  209.641425
# 11        807  2007-05-09 00:00:00              3667   7.94         252
# 12        807  2007-05-10 00:00:00              3667   9.53         250
# 13        807  2007-05-11 00:00:00              3667  11.11         240
# 14        807  2007-05-12 00:00:00              3667   12.7         228
# 15        807  2009-08-18 00:00:00              3579   7.94  259.608696
# 16        807  2009-08-22 00:00:00              3579   9.53  239.423077
# 17        807  2009-08-26 00:00:00              3579  11.11  213.428571
# 18        807  2009-08-30 00:00:00              3579   12.7  194.242424
# 19        807  2009-09-03 00:00:00              3579  14.29         166
# 20        807  2011-09-09 00:00:00            3582.5   9.53         206
# 21      20503  2007-10-03 00:00:00              3653   7.94       323.1
# 22      20503  2007-10-04 00:00:00              3653   9.53  272.692308
# 23      20503  2007-10-05 00:00:00              3653   12.7  202.153846
# 24      20503  2007-10-06 00:00:00              3653  14.29  165.846154
# 25      20503  2007-10-07 00:00:00              3653  15.88  138.866667
#
#           Рзаб        Pлин      Руст.1      Рзаб.1        Рлин  ...  \
# 1        370.1       101.8         249       359.6       101.8  ...
# 2        364.6       101.3         231       338.1       102.4  ...
# 3        357.1       101.6         211       314.8       100.6  ...
# 4        347.4        98.4         187       291.5          99  ...
# 5        337.7        99.2         169       270.3        99.5  ...
# 6        286.4  106.361669       199.5       286.6      106.19  ...
# 7   391.823775           -   284.31795  391.823775           -  ...
# 8     384.2244           -   270.94305    384.2244           -  ...
# 9   371.912399           -  245.510475  371.912399           -  ...
# 10  346.192061           -  209.641425  346.192061           -  ...
# 11  354.333525  102.932004         252       354.2  101.565484  ...
# 12       350.2  103.186902         250       349.1  103.322581  ...
# 13         344  105.671499         240       344.1   105.58871  ...
# 14       336.7  108.100063         228         343  108.144839  ...
# 15      365.86  103.471415         259       365.9  101.420323  ...
# 16      342.27  103.200466         239       342.3      104.18  ...
# 17      312.27  103.187111         212       312.3       103.0  ...
# 18      291.74  103.229928         194       291.7  103.917419  ...
# 19      263.03   107.37756         166         263  107.536667  ...
# 20         292  105.507978         206         292      105.03  ...
# 21       440.5  108.886435         314       442.7   99.167355  ...
# 22       388.7   89.652839         268       388.6   86.747194  ...
# 23       308.8   97.877045         197       308.7   92.457903  ...
# 24       270.5    79.95275         162       270.4   81.146774  ...
# 25       239.3   80.732932         136       239.3   79.541129  ...
#
#    Рпл. Тек (Карноухов)    Pсб       Pсб.1      Ro_g   Ro_c  Ro_w  \
# 1                     -   93.6   92.376018  0.806017    801  1000
# 2                     -   92.9   91.685171  0.806017    801  1000
# 3                     -   91.4   90.204787  0.806017    801  1000
# 4                     -   89.2   88.033555  0.806017    801  1000
# 5                     -   89.7   88.527017  0.806017    801  1000
# 6                     -   90.7    89.51394    0.8127  789.8  1000
# 7                  51.7    NaN         NaN       NaN    NaN   NaN
# 8                  51.7    NaN         NaN       NaN    NaN   NaN
# 9                  51.7    NaN         NaN       NaN    NaN   NaN
# 10                 51.7    NaN         NaN       NaN    NaN   NaN
# 11                 50.1  100.9   99.580558       NaN    787   NaN
# 12                 50.1  100.1   98.791019       NaN    787   NaN
# 13                 50.1    102  100.666173       NaN    787   NaN
# 14                 50.1  103.8  102.442635       NaN    787   NaN
# 15                    -   93.2   91.981248       NaN  793.7   NaN
# 16                    -     92   90.796941       NaN  793.7   NaN
# 17                    -   93.7    92.47471       NaN  793.7   NaN
# 18                    -   89.6   88.428325       NaN  793.7   NaN
# 19                    -   90.3   89.119171       NaN  793.7   NaN
# 20                  NaN   92.1   90.895633       NaN    783   NaN
# 21                 56.8   99.4   98.100173  0.787416    798  1000
# 22                 56.8   99.7    98.39625  0.787416    798  1000
# 23                 56.8   99.2   97.902788  0.787416    798  1000
# 24                 56.8   98.9   97.606711  0.787416    798  1000
# 25                 56.8  100.8   99.481865  0.787416    798  1000
#
#    Удельная плотность газа    G_total         КГФ  КГФ.1
# 1                  0.669449  2.782623    311.9094    NaN
# 2                  0.669449  3.697781    288.6003    NaN
# 3                  0.669449  4.515073    248.7906    NaN
# 4                  0.669449  5.217673    223.5591    NaN
# 5                  0.669449  5.765092    215.1486    NaN
# 6                     0.675  3.076542  241.130794    NaN
# 7                       NaN       NaN         NaN    NaN
# 8                       NaN       NaN         NaN    NaN
# 9                       NaN       NaN         NaN    NaN
# 10                      NaN       NaN         NaN    NaN
# 11                    0.659       NaN         NaN  0.188
# 12                    0.659       NaN         NaN  0.178
# 13                    0.659       NaN         NaN  0.169
# 14                    0.659       NaN         NaN  0.162
# 15                    0.661       NaN         NaN   0.23
# 16                    0.661       NaN         NaN  0.201
# 17                    0.661       NaN         NaN  0.172
# 18                    0.661       NaN         NaN  0.157
# 19                    0.661       NaN         NaN  0.141
# 20                    0.672       NaN         NaN  0.172
# 21                    0.654   4.23237  385.415949    NaN
# 22                    0.654  4.714503   295.50288    NaN
# 23                    0.654   5.72787  255.681127    NaN
# 24                    0.654  5.775314  233.960444    NaN
# 25                    0.654    5.7649  223.109461    NaN
#
# [25 rows x 34 columns]

# %%
df = df.rename(columns = {'Unnamed: 0' :'№', 'Unnamed: 1':'Date'})

# %%
df.columns
# Out:
# Index(['№', 'Date', 'Глубина манометра', 'Dшт', 'Руст', 'Рзаб', 'Pлин',
#        'Руст.1', 'Рзаб.1', 'Рлин', 'Туст', 'Тна шлейфе', 'Тзаб', 'Tлин',
#        'Дебит газа', 'Дебит ст. конд.', 'Дебит воды', 'Дебит смеси',
#        'Дебит гааз', 'Дебит кон нестабильный', 'Дебит воды.1', 'Нэф',
#        'Рпл. Тек (послед точка на КВД)', 'Рпл. Тек (Расчет по КВД)',
#        'Рпл. Тек (Карноухов)', 'Pсб', 'Pсб.1', 'Ro_g', 'Ro_c', 'Ro_w',
#        'Удельная плотность газа ', 'G_total', 'КГФ', 'КГФ.1'],
#       dtype='object')

# %%
df.head(100)
# Out:
#          №                 Date Глубина манометра    Dшт        Руст   Рзаб  \
# 1      804  2008-06-05 00:00:00            3576.3   7.94       249.6  370.1
# 2      804  2008-06-06 00:00:00            3576.3   9.53       233.5  364.6
# 3      804  2008-06-07 00:00:00            3576.3  11.11       213.4  357.1
# 4      804  2008-06-08 00:00:00            3576.3   12.7       191.6  347.4
# 5      804  2008-06-09 00:00:00            3576.3  14.29       171.9  337.7
# ..     ...                  ...               ...    ...         ...    ...
# 96   21303  2010-04-08 00:00:00            3668.5  11.11         239    334
# 97   21303  2010-04-13 00:00:00            3668.5   12.7  223.888889    326
# 98   21303  2010-04-16 00:00:00            3668.5  14.29         206    318
# 99   21303  2011-07-04 00:00:00                 -   12.7         199      -
# 100  22102  2007-06-10 00:00:00            3548.5   6.35         187  300.5
#
#            Pлин Руст.1 Рзаб.1       Рлин  ... Рпл. Тек (Карноухов)    Pсб  \
# 1         101.8    249  359.6      101.8  ...                    -   93.6
# 2         101.3    231  338.1      102.4  ...                    -   92.9
# 3         101.6    211  314.8      100.6  ...                    -   91.4
# 4          98.4    187  291.5         99  ...                    -   89.2
# 5          99.2    169  270.3       99.5  ...                    -   89.7
# ..          ...    ...    ...        ...  ...                  ...    ...
# 96    95.505153    239  331.7  95.884226  ...                 49.7   88.1
# 97     94.89209    223    324  95.523484  ...                 49.7   88.8
# 98    97.270564    205  312.5  95.523484  ...                 49.7   88.9
# 99   100.247185    199      -     100.08  ...                    -     91
# 100  103.757532    187    300  107.89592  ...                 44.6  101.1
#
#          Pсб.1      Ro_g    Ro_c  Ro_w Удельная плотность газа    G_total  \
# 1    92.376018  0.806017     801  1000                 0.669449  2.782623
# 2    91.685171  0.806017     801  1000                 0.669449  3.697781
# 3    90.204787  0.806017     801  1000                 0.669449  4.515073
# 4    88.033555  0.806017     801  1000                 0.669449  5.217673
# 5    88.527017  0.806017     801  1000                 0.669449  5.765092
# ..         ...       ...     ...   ...                      ...       ...
# 96    86.94794       NaN  782.53   NaN                     0.66       NaN
# 97   87.638786       NaN  782.53   NaN                     0.66       NaN
# 98   87.737478       NaN  782.53   NaN                     0.66       NaN
# 99   89.810017       NaN     NaN   NaN                      NaN       NaN
# 100  99.777942       NaN     NaN   NaN                      NaN       NaN
#
#           КГФ  КГФ.1
# 1    311.9094    NaN
# 2    288.6003    NaN
# 3    248.7906    NaN
# 4    223.5591    NaN
# 5    215.1486    NaN
# ..        ...    ...
# 96        NaN  0.141
# 97        NaN  0.139
# 98        NaN  0.132
# 99        NaN    NaN
# 100       NaN    NaN
#
# [100 rows x 34 columns]

# %%
df['КГФ'] = df['КГФ'].mask(df['КГФ'].isna(), df['КГФ.1'])
df = df.drop(['КГФ.1'], axis=1)

# %% [markdown]
# # 1. Удалить строки, где обе целевых переменные пустые

# %%
#df= df[(df[df != 'NaN') & (df['КГФ'] != 'NaN')]

# %%
df.dropna(axis = 0, subset = ['G_total','КГФ'], how = 'all', inplace = True)

# %%
df.head(100)
# Out:
#          №                 Date Глубина манометра    Dшт        Руст   Рзаб  \
# 1      804  2008-06-05 00:00:00            3576.3   7.94       249.6  370.1
# 2      804  2008-06-06 00:00:00            3576.3   9.53       233.5  364.6
# 3      804  2008-06-07 00:00:00            3576.3  11.11       213.4  357.1
# 4      804  2008-06-08 00:00:00            3576.3   12.7       191.6  347.4
# 5      804  2008-06-09 00:00:00            3576.3  14.29       171.9  337.7
# ..     ...                  ...               ...    ...         ...    ...
# 164  22503  2009-01-28 00:00:00              3284   12.7         215  307.8
# 165  22503  2009-02-01 00:00:00              3284  14.29         198  293.6
# 166  22503  2010-08-16 00:00:00            3288.6   7.94  231.229167  309.1
# 167  22503  2010-08-20 00:00:00            3288.6  11.11  217.201681  293.9
# 168  22503  2011-10-02 00:00:00            3289.8   9.53         199    271
#
#           Pлин Руст.1 Рзаб.1    Рлин  ... Рпл. Тек (Расчет по КВД)  \
# 1        101.8    249  359.6   101.8  ...                     56.5
# 2        101.3    231  338.1   102.4  ...                     56.5
# 3        101.6    211  314.8   100.6  ...                     56.5
# 4         98.4    187  291.5      99  ...                     56.5
# 5         99.2    169  270.3    99.5  ...                     56.5
# ..         ...    ...    ...     ...  ...                      ...
# 164       98.6    215  308.1    97.2  ...                     40.5
# 165       98.5    197  293.9    98.4  ...                     40.5
# 166       92.6    230  307.1    92.7  ...                        -
# 167       93.1    215  293.9    93.3  ...                        -
# 168  95.945951    199  272.3  94.637  ...                     39.9
#
#     Рпл. Тек (Карноухов)   Pсб      Pсб.1      Ro_g   Ro_c  Ro_w  \
# 1                      -  93.6  92.376018  0.806017    801  1000
# 2                      -  92.9  91.685171  0.806017    801  1000
# 3                      -  91.4  90.204787  0.806017    801  1000
# 4                      -  89.2  88.033555  0.806017    801  1000
# 5                      -  89.7  88.527017  0.806017    801  1000
# ..                   ...   ...        ...       ...    ...   ...
# 164                 41.6  94.4  93.165556       NaN    782   NaN
# 165                 41.6    94  92.770787       NaN    782   NaN
# 166                    -  89.9  88.724402       NaN  779.6   NaN
# 167                    -  90.8  89.612633       NaN  779.6   NaN
# 168                    -    94  92.770787       NaN  772.6   NaN
#
#     Удельная плотность газа    G_total       КГФ
# 1                   0.669449  2.782623  311.9094
# 2                   0.669449  3.697781  288.6003
# 3                   0.669449  4.515073  248.7906
# 4                   0.669449  5.217673  223.5591
# 5                   0.669449  5.765092  215.1486
# ..                       ...       ...       ...
# 164                     0.66       NaN     0.153
# 165                     0.66       NaN     0.147
# 166                    0.668       NaN     0.182
# 167                    0.668       NaN     0.145
# 168                    0.671       NaN     0.139
#
# [93 rows x 33 columns]

# %% [markdown]
# # 2. Пропуски заполнить NaN

# %%
name_columns =  df.columns

# %%
for name in name_columns:
    df.loc[(df[name] == '-')|(df[name] == 'не спускался'), name] = np.nan

# %%
df
# Out:
#          №                 Date Глубина манометра    Dшт        Руст   Рзаб  \
# 1      804  2008-06-05 00:00:00            3576.3   7.94       249.6  370.1
# 2      804  2008-06-06 00:00:00            3576.3   9.53       233.5  364.6
# 3      804  2008-06-07 00:00:00            3576.3  11.11       213.4  357.1
# 4      804  2008-06-08 00:00:00            3576.3   12.7       191.6  347.4
# 5      804  2008-06-09 00:00:00            3576.3  14.29       171.9  337.7
# ..     ...                  ...               ...    ...         ...    ...
# 164  22503  2009-01-28 00:00:00              3284   12.7         215  307.8
# 165  22503  2009-02-01 00:00:00              3284  14.29         198  293.6
# 166  22503  2010-08-16 00:00:00            3288.6   7.94  231.229167  309.1
# 167  22503  2010-08-20 00:00:00            3288.6  11.11  217.201681  293.9
# 168  22503  2011-10-02 00:00:00            3289.8   9.53         199    271
#
#           Pлин Руст.1 Рзаб.1    Рлин  ... Рпл. Тек (Расчет по КВД)  \
# 1        101.8    249  359.6   101.8  ...                     56.5
# 2        101.3    231  338.1   102.4  ...                     56.5
# 3        101.6    211  314.8   100.6  ...                     56.5
# 4         98.4    187  291.5      99  ...                     56.5
# 5         99.2    169  270.3    99.5  ...                     56.5
# ..         ...    ...    ...     ...  ...                      ...
# 164       98.6    215  308.1    97.2  ...                     40.5
# 165       98.5    197  293.9    98.4  ...                     40.5
# 166       92.6    230  307.1    92.7  ...                      NaN
# 167       93.1    215  293.9    93.3  ...                      NaN
# 168  95.945951    199  272.3  94.637  ...                     39.9
#
#     Рпл. Тек (Карноухов)   Pсб      Pсб.1      Ro_g   Ro_c  Ro_w  \
# 1                    NaN  93.6  92.376018  0.806017    801  1000
# 2                    NaN  92.9  91.685171  0.806017    801  1000
# 3                    NaN  91.4  90.204787  0.806017    801  1000
# 4                    NaN  89.2  88.033555  0.806017    801  1000
# 5                    NaN  89.7  88.527017  0.806017    801  1000
# ..                   ...   ...        ...       ...    ...   ...
# 164                 41.6  94.4  93.165556       NaN    782   NaN
# 165                 41.6    94  92.770787       NaN    782   NaN
# 166                  NaN  89.9  88.724402       NaN  779.6   NaN
# 167                  NaN  90.8  89.612633       NaN  779.6   NaN
# 168                  NaN    94  92.770787       NaN  772.6   NaN
#
#     Удельная плотность газа    G_total       КГФ
# 1                   0.669449  2.782623  311.9094
# 2                   0.669449  3.697781  288.6003
# 3                   0.669449  4.515073  248.7906
# 4                   0.669449  5.217673  223.5591
# 5                   0.669449  5.765092  215.1486
# ..                       ...       ...       ...
# 164                     0.66       NaN     0.153
# 165                     0.66       NaN     0.147
# 166                    0.668       NaN     0.182
# 167                    0.668       NaN     0.145
# 168                    0.671       NaN     0.139
#
# [93 rows x 33 columns]

# %% [markdown]
# ## Замена на -100

# %%
df_norm = df
for name in name_columns:
    df_norm[name] = df[name]. fillna (-100)

# %%
df
# Out:
#          №       Date  Глубина манометра    Dшт        Руст   Рзаб  \
# 1      804 2008-06-05             3576.3   7.94  249.600000  370.1
# 2      804 2008-06-06             3576.3   9.53  233.500000  364.6
# 3      804 2008-06-07             3576.3  11.11  213.400000  357.1
# 4      804 2008-06-08             3576.3  12.70  191.600000  347.4
# 5      804 2008-06-09             3576.3  14.29  171.900000  337.7
# ..     ...        ...                ...    ...         ...    ...
# 164  22503 2009-01-28             3284.0  12.70  215.000000  307.8
# 165  22503 2009-02-01             3284.0  14.29  198.000000  293.6
# 166  22503 2010-08-16             3288.6   7.94  231.229167  309.1
# 167  22503 2010-08-20             3288.6  11.11  217.201681  293.9
# 168  22503 2011-10-02             3289.8   9.53  199.000000  271.0
#
#            Pлин  Руст.1  Рзаб.1     Рлин  ...  Рпл. Тек (Расчет по КВД)  \
# 1    101.800000   249.0   359.6  101.800  ...                      56.5
# 2    101.300000   231.0   338.1  102.400  ...                      56.5
# 3    101.600000   211.0   314.8  100.600  ...                      56.5
# 4     98.400000   187.0   291.5   99.000  ...                      56.5
# 5     99.200000   169.0   270.3   99.500  ...                      56.5
# ..          ...     ...     ...      ...  ...                       ...
# 164   98.600000   215.0   308.1   97.200  ...                      40.5
# 165   98.500000   197.0   293.9   98.400  ...                      40.5
# 166   92.600000   230.0   307.1   92.700  ...                    -100.0
# 167   93.100000   215.0   293.9   93.300  ...                    -100.0
# 168   95.945951   199.0   272.3   94.637  ...                      39.9
#
#      Рпл. Тек (Карноухов)   Pсб      Pсб.1        Ro_g   Ro_c  Ro_w  \
# 1                  -100.0  93.6  92.376018    0.806017  801.0  1000
# 2                  -100.0  92.9  91.685171    0.806017  801.0  1000
# 3                  -100.0  91.4  90.204787    0.806017  801.0  1000
# 4                  -100.0  89.2  88.033555    0.806017  801.0  1000
# 5                  -100.0  89.7  88.527017    0.806017  801.0  1000
# ..                    ...   ...        ...         ...    ...   ...
# 164                  41.6  94.4  93.165556 -100.000000  782.0  -100
# 165                  41.6  94.0  92.770787 -100.000000  782.0  -100
# 166                -100.0  89.9  88.724402 -100.000000  779.6  -100
# 167                -100.0  90.8  89.612633 -100.000000  779.6  -100
# 168                -100.0  94.0  92.770787 -100.000000  772.6  -100
#
#      Удельная плотность газа      G_total       КГФ
# 1                    0.669449    2.782623  311.9094
# 2                    0.669449    3.697781  288.6003
# 3                    0.669449    4.515073  248.7906
# 4                    0.669449    5.217673  223.5591
# 5                    0.669449    5.765092  215.1486
# ..                        ...         ...       ...
# 164                  0.660000 -100.000000    0.1530
# 165                  0.660000 -100.000000    0.1470
# 166                  0.668000 -100.000000    0.1820
# 167                  0.668000 -100.000000    0.1450
# 168                  0.671000 -100.000000    0.1390
#
# [93 rows x 33 columns]

# %% [markdown]
# # 3. Построить гистраграмму важности признаков по критерию gain_ratio (нормированный прирост информации)

# %%
del df_norm["№"]
del df_norm["Date"]
df_norm = df_norm.apply(pd.to_numeric)
xTrain = df_norm.iloc[:,0:29]
yTrain = df_norm.iloc[:,29:32]
print(df_norm)

# %%
del df_norm["КГФ"]
del df_norm["G_total"]
# Out:
#      Глубина манометра    Dшт        Руст   Рзаб        Pлин  Руст.1  Рзаб.1  \
# 1               3576.3   7.94  249.600000  370.1  101.800000   249.0   359.6
# 2               3576.3   9.53  233.500000  364.6  101.300000   231.0   338.1
# 3               3576.3  11.11  213.400000  357.1  101.600000   211.0   314.8
# 4               3576.3  12.70  191.600000  347.4   98.400000   187.0   291.5
# 5               3576.3  14.29  171.900000  337.7   99.200000   169.0   270.3
# ..                 ...    ...         ...    ...         ...     ...     ...
# 164             3284.0  12.70  215.000000  307.8   98.600000   215.0   308.1
# 165             3284.0  14.29  198.000000  293.6   98.500000   197.0   293.9
# 166             3288.6   7.94  231.229167  309.1   92.600000   230.0   307.1
# 167             3288.6  11.11  217.201681  293.9   93.100000   215.0   293.9
# 168             3289.8   9.53  199.000000  271.0   95.945951   199.0   272.3
#
#         Рлин  Туст  Тна шлейфе  ...  Рпл. Тек (Расчет по КВД)  \
# 1    101.800  53.0        31.7  ...                      56.5
# 2    102.400  58.8        37.6  ...                      56.5
# 3    100.600  63.6        42.8  ...                      56.5
# 4     99.000  64.7        46.2  ...                      56.5
# 5     99.500  64.0        49.4  ...                      56.5
# ..       ...   ...         ...  ...                       ...
# 164   97.200  65.0        45.8  ...                      40.5
# 165   98.400  66.9        49.8  ...                      40.5
# 166   92.700  51.0      -100.0  ...                    -100.0
# 167   93.300  60.0      -100.0  ...                    -100.0
# 168   94.637  56.0      -100.0  ...                      39.9
#
#      Рпл. Тек (Карноухов)   Pсб      Pсб.1        Ro_g   Ro_c  Ro_w  \
# 1                  -100.0  93.6  92.376018    0.806017  801.0  1000
# 2                  -100.0  92.9  91.685171    0.806017  801.0  1000
# 3                  -100.0  91.4  90.204787    0.806017  801.0  1000
# 4                  -100.0  89.2  88.033555    0.806017  801.0  1000
# 5                  -100.0  89.7  88.527017    0.806017  801.0  1000
# ..                    ...   ...        ...         ...    ...   ...
# 164                  41.6  94.4  93.165556 -100.000000  782.0  -100
# 165                  41.6  94.0  92.770787 -100.000000  782.0  -100
# 166                -100.0  89.9  88.724402 -100.000000  779.6  -100
# 167                -100.0  90.8  89.612633 -100.000000  779.6  -100
# 168                -100.0  94.0  92.770787 -100.000000  772.6  -100
#
#      Удельная плотность газа      G_total       КГФ
# 1                    0.669449    2.782623  311.9094
# 2                    0.669449    3.697781  288.6003
# 3                    0.669449    4.515073  248.7906
# 4                    0.669449    5.217673  223.5591
# 5                    0.669449    5.765092  215.1486
# ..                        ...         ...       ...
# 164                  0.660000 -100.000000    0.1530
# 165                  0.660000 -100.000000    0.1470
# 166                  0.668000 -100.000000    0.1820
# 167                  0.668000 -100.000000    0.1450
# 168                  0.671000 -100.000000    0.1390
#
# [93 rows x 31 columns]

# %%
clf = RandomForestRegressor()
clf.fit(xTrain, yTrain)
# Out:
# C:\Users\misha\AppData\Local\Temp\ipykernel_9528\3851455745.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(xTrain, yTrain)
# RandomForestRegressor()

# %%
print(xTrain)
# Out:
#      Глубина манометра    Dшт        Руст   Рзаб        Pлин  Руст.1  Рзаб.1  \
# 1               3576.3   7.94  249.600000  370.1  101.800000   249.0   359.6
# 2               3576.3   9.53  233.500000  364.6  101.300000   231.0   338.1
# 3               3576.3  11.11  213.400000  357.1  101.600000   211.0   314.8
# 4               3576.3  12.70  191.600000  347.4   98.400000   187.0   291.5
# 5               3576.3  14.29  171.900000  337.7   99.200000   169.0   270.3
# ..                 ...    ...         ...    ...         ...     ...     ...
# 164             3284.0  12.70  215.000000  307.8   98.600000   215.0   308.1
# 165             3284.0  14.29  198.000000  293.6   98.500000   197.0   293.9
# 166             3288.6   7.94  231.229167  309.1   92.600000   230.0   307.1
# 167             3288.6  11.11  217.201681  293.9   93.100000   215.0   293.9
# 168             3289.8   9.53  199.000000  271.0   95.945951   199.0   272.3
#
#         Рлин  Туст  Тна шлейфе  ...      Нэф  Рпл. Тек (послед точка на КВД)  \
# 1    101.800  53.0        31.7  ...  56.8000                           45.25
# 2    102.400  58.8        37.6  ...  56.8000                           45.25
# 3    100.600  63.6        42.8  ...  56.8000                           45.25
# 4     99.000  64.7        46.2  ...  56.8000                           45.25
# 5     99.500  64.0        49.4  ...  56.8000                           45.25
# ..       ...   ...         ...  ...      ...                             ...
# 164   97.200  65.0        45.8  ...  44.5000                           35.28
# 165   98.400  66.9        49.8  ...  44.5000                           35.28
# 166   92.700  51.0      -100.0  ...  48.3747                           33.21
# 167   93.300  60.0      -100.0  ...  48.3747                           33.21
# 168   94.637  56.0      -100.0  ...  48.4000                         -100.00
#
#      Рпл. Тек (Расчет по КВД)  Рпл. Тек (Карноухов)   Pсб      Pсб.1  \
# 1                        56.5                -100.0  93.6  92.376018
# 2                        56.5                -100.0  92.9  91.685171
# 3                        56.5                -100.0  91.4  90.204787
# 4                        56.5                -100.0  89.2  88.033555
# 5                        56.5                -100.0  89.7  88.527017
# ..                        ...                   ...   ...        ...
# 164                      40.5                  41.6  94.4  93.165556
# 165                      40.5                  41.6  94.0  92.770787
# 166                    -100.0                -100.0  89.9  88.724402
# 167                    -100.0                -100.0  90.8  89.612633
# 168                      39.9                -100.0  94.0  92.770787
#
#            Ro_g   Ro_c  Ro_w  Удельная плотность газа
# 1      0.806017  801.0  1000                  0.669449
# 2      0.806017  801.0  1000                  0.669449
# 3      0.806017  801.0  1000                  0.669449
# 4      0.806017  801.0  1000                  0.669449
# 5      0.806017  801.0  1000                  0.669449
# ..          ...    ...   ...                       ...
# 164 -100.000000  782.0  -100                  0.660000
# 165 -100.000000  782.0  -100                  0.660000
# 166 -100.000000  779.6  -100                  0.668000
# 167 -100.000000  779.6  -100                  0.668000
# 168 -100.000000  772.6  -100                  0.671000
#
# [93 rows x 29 columns]

# %%
print(yTrain)
# Out:
#           КГФ
# 1    311.9094
# 2    288.6003
# 3    248.7906
# 4    223.5591
# 5    215.1486
# ..        ...
# 164    0.1530
# 165    0.1470
# 166    0.1820
# 167    0.1450
# 168    0.1390
#
# [93 rows x 1 columns]

# %%
df_norm.head()
# Out:
#    Глубина манометра    Dшт   Руст   Рзаб   Pлин  Руст.1  Рзаб.1   Рлин  Туст  \
# 1             3576.3   7.94  249.6  370.1  101.8   249.0   359.6  101.8  53.0
# 2             3576.3   9.53  233.5  364.6  101.3   231.0   338.1  102.4  58.8
# 3             3576.3  11.11  213.4  357.1  101.6   211.0   314.8  100.6  63.6
# 4             3576.3  12.70  191.6  347.4   98.4   187.0   291.5   99.0  64.7
# 5             3576.3  14.29  171.9  337.7   99.2   169.0   270.3   99.5  64.0
#
#    Тна шлейфе  ...   Нэф  Рпл. Тек (послед точка на КВД)  \
# 1        31.7  ...  56.8                           45.25
# 2        37.6  ...  56.8                           45.25
# 3        42.8  ...  56.8                           45.25
# 4        46.2  ...  56.8                           45.25
# 5        49.4  ...  56.8                           45.25
#
#    Рпл. Тек (Расчет по КВД)  Рпл. Тек (Карноухов)   Pсб      Pсб.1      Ro_g  \
# 1                      56.5                -100.0  93.6  92.376018  0.806017
# 2                      56.5                -100.0  92.9  91.685171  0.806017
# 3                      56.5                -100.0  91.4  90.204787  0.806017
# 4                      56.5                -100.0  89.2  88.033555  0.806017
# 5                      56.5                -100.0  89.7  88.527017  0.806017
#
#     Ro_c  Ro_w  Удельная плотность газа
# 1  801.0  1000                  0.669449
# 2  801.0  1000                  0.669449
# 3  801.0  1000                  0.669449
# 4  801.0  1000                  0.669449
# 5  801.0  1000                  0.669449
#
# [5 rows x 29 columns]

# %%
name_columns =  df_norm.columns
plt.figure(figsize=(8,8))
plt.bar(name_columns, clf.feature_importances_, color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# ### Для G_total

# %%
df = df.drop(['№','Date', 'Ro_w'], axis=1)

# %%
df = df.apply(pd.to_numeric)

# %%
df.info()

# %%
clf = RandomForestRegressor()

# %%
#df_norm = df.copy()
df_norm = df.drop(['G_total','КГФ'], axis=1)

# %%
label = df["G_total"]

# %%
df.head(20)

# %%
print(df_norm)

# %%
#label_encoder = preprocessing.LabelEncoder()
#label = label_encoder.fit_transform(label)

# %%
clf.fit(df_norm, label)

# %%
name_columns =  df_norm.columns

# %%
plt.figure(figsize=(14,14))
plt.bar(name_columns, clf.feature_importances_, color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# ### Для КГФ

# %%
clf_2 = RandomForestRegressor()

# %%
label = df["КГФ"]

# %%
#label_encoder = preprocessing.LabelEncoder()
#label = label_encoder.fit_transform(label)

# %%
clf_2.fit(df_norm, label)

# %%
plt.figure(figsize=(14,14))
plt.bar(name_columns, clf_2.feature_importances_, color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# # 4. Построить тепловую карту признаков (матрица корреляций всех признаков со всеми, в том числе целевыми переменными), для удобства коэффициент корреляции берите по модулю

# %%
df.info()

# %%
#df = abs(df)

# %%
plt.subplots(figsize=(25, 20))
sns.heatmap(abs(df.corr()), annot = True, fmt='.1f')
#sns.heatmap(df.corr(), annot = True, fmt='.1g')

# %% [markdown]
# # 5. Для каждого признака построить график распределения с отложенными на нем линиями первого и третьего квартилей

# %%
name_columns = df.columns
name_columns

# %%
def create_graph(name):
    #sns.distplot(df[name])
    sns.kdeplot(df[name], shade=True)
    plt.axvline(column_first_quantile(name), 1, 0.007, color = 'red')
    plt.axvline(column_third_quantile(name), 1, 0.007, color = 'red')
    #fig = sns_plot.get_figure()
    plt.show()

# %%
for name in name_columns:
    create_graph(name)

# %% [markdown]
# # 6. Для каждого признака посчитать элементы описательной статистики

# %%
df

# %%
name_columns = df.columns

# %%
def column_count(name): #количество
    return len(df[name])

def column_min(name):
    return df[name].min()

def column_first_quantile(name):
    return df[name].quantile(0.25)

def column_median(name):
    return df[name].quantile(0.5)

def column_third_quantile(name):
    return df[name].quantile(0.75)

def column_max(name):
    return df[name].max()

def column_mean(name):
    return df[name].mean()

def column_std(name):
    return df[name].std()

def column_power(name):
    return df[name].value_counts().count()

def interquartile_range(name):
    return column_third_quantile(name) - column_first_quantile(name)

# %%
for name in name_columns:
    print(f'{name}: ')
    print(f"\tCount: {column_count(name)}\n\tMin: {column_min(name)}\n\tFirst quantile: {column_first_quantile(name)}\n\tMedian: {column_median(name)}\n\tThird quantile: {column_third_quantile(name)}\n\tMax: {column_max(name)}\n\tMean: {column_mean(name)}\n\tStd: {column_std(name)}\n\tPower: {column_power(name)}\n\tInterquartile range: {interquartile_range(name)}\n")

# %% [markdown]
# ## Исходя из полученных данных, мы можем сделать вывод о том, что нужно оставить признаки:
# 1. "Глубина манометра";
# 2. "Рлин";
# 3. "Дебит ст. конд";
# 4. "Нэф";
# 5. "Рпл. Тек (послед точка на КВД)";
# 6. "Рпл. Тек (Расчет по КВД)".
